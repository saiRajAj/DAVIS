# %% [markdown]
# <a href="https://colab.research.google.com/github/saiRajAj/DAVIS/blob/main/strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Predefined Functions

# %%
name = "Joe"
l = len(name)
print(l)
# Out:
# 3

# %%
age = 20
t = type(age)
print(t)
# Out:
# <class 'int'>

# %%
num = input("Enter Your Name : ")
n = num * 2
n = int(num) * 2
print(n)
# Out:
# Enter Your Name : 6
# 12

# %% [markdown]
# String in Python is a sequence of characters enclosed with the single or double quotes

# %%
name = "Sai"
city = "Pune"
message = "Hello Everyone..."

# %%
name = "Python"
print(name[0])
print(name[len(name) - 1])
# Out:
# P
# n

# %% [markdown]
# String Functions

# %%
name = "python"
print(name.upper())
# Out:
# PYTHON

# %%
text = "    hello       "
print(text.strip())
# Out:
# hello

# %%
msg = "hello"
print(msg.replace("h","H"))
# Out:
# Hello

# %%
text = "I love programs in "
print(text.find("programs"))

# %%
sen = "python is good than other"
print(sen.split())
# Out:
# ['python', 'is', 'good', 'than', 'other']

# %%
name = input("Enter Your name : ")
name = name.replace(" ","")
username = '@'+name.lower()+str(len(name))
print(username)
# Out:
# Enter Your name : Sairaj
# @sairaj6
